# %% [markdown]
# # Enterprise Agentic Hybrid RAG

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# ## Configuration

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Load Documents

# %% [markdown]
# ## Chunk Documents

# %% [markdown]
# ## Embeddings

# %% [markdown]
# ## Qdrant

# %% [markdown]
# ## BM25

# %% [markdown]
# ## Hybrid Retrieval

# %% [markdown]
# ## Reranking

# %% [markdown]
# ## LangGraph

# %% [markdown]
# ## Evaluation
